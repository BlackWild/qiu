# %%
JUPYTER_NAME = "13-lens-simulation-after-classical-numerics"

# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as constants
from qiskit import transpile
from qiskit.circuit import ClassicalRegister, QuantumCircuit, QuantumRegister
from qiskit.quantum_info import Operator, Statevector, partial_trace
from qiskit_aer import AerSimulator
from qiskit_aer_encore.simulator import generate_aer_simulator
from qiskit_hamiltonian_simulation.time_independent.direct import (
    MomentumDomainEvolutionQuadratic,
    PositionDomainEvolutionQuadratic,
)
from qiskit_hamiltonian_simulation.time_independent.sample_based import (
    KineticEvolutionSampleBased,
    PotentialEvolutionSampleBased,
)
from qiskit_phase_propagator.sample_based_manual import (
    phase_propagate_state_with_arbitrary_signal,
)

# from qiskit_phase_propagator.sample_based import (
#     QuadraticSignalSampleBasedPhasePropagator,
# )
from qiskit_signals.helper_types import EncodingType
from qiskit_signals.quantum_axis import (
    AngularWavenumberAxis,
    MomentumAxis,
    PositionAxis,
)
from qiskit_signals.quantum_signal import GenericQuantumSignal, QuadraticQuantumSignal
from qiskit_signals.sample_based_signal import ArbitrarySignalForSampleBasedProtocol
from wave_optics_propagation.analytics import (
    free_space_propagated_gaussian_wavefront,
    gaussian_signal,
    propagated_gaussian_wavefront_hitting_lens,
)
from wave_optics_propagation.big_matrix_version import big_matrix_circ
from wave_optics_propagation.elements import (
    free_space_signal_generator,
    radius_of_convex_planar_lens_as_a_func_of_z,
    thin_lens_signal_generator,
    thin_transparent_plate_signal_generator,
)
from wave_optics_propagation.storage import (
    save_initial_parameters,
    save_numpy_results,
)
from wave_optics_propagation.visualization import plot_wavefunction

# %%
experiment_datetime = datetime.now()

# %% [markdown]
# ---

# %% [markdown]
# ### Initial parameters

# %%
# beam parameters
# vacuum_wavelength = 1e-6
vacuum_wavelength = 1e-6 * 1e1
# beam_FWHM = 5e-3 * 1e-2
beam_FWHM = 20e-3 * 1e-2

# lens parameters
focal_length = 200e-3 * 1e-2
# lens_diameter = 25e-3
# refractive_index = 1.5
refractive_index = 1.25

# free space propagation parameters
propagation_after_lens = 1.5 * focal_length

# simulation parameters
transverse_length = 100e-3 * 1e-2  # transverse simulation window
num_of_steps_after_lens = 10
lens_slices = 10000
num_qubits = 8
max_delta = 0.025

# lens_diameter = 50e-3 * 1e-2
lens_diameter = transverse_length

# %% [markdown]
# ### Constants

# %%
c = constants.c
# hbar = constants.hbar

# %% [markdown]
# ### Derived parameters

# %%
# geometry
radius_of_curvature = focal_length * (refractive_index - 1)
lens_radius = lens_diameter / 2
lens_thickness = radius_of_curvature - np.sqrt(radius_of_curvature**2 - lens_radius**2)


k_0 = 2 * constants.pi / vacuum_wavelength
reduced_wavelength = vacuum_wavelength / refractive_index

dimension = 2**num_qubits
delta_x = transverse_length / dimension

gaussian_mean = transverse_length / 2
gaussian_beam_waist = beam_FWHM / np.sqrt(2 * np.log(2))
# gaussian_sigma = gaussian_beam_waist / np.sqrt(2)

# vacuum_rayleigh_length = (np.pi * gaussian_beam_waist**2) / vacuum_wavelength

lens_slice_thickness = lens_thickness / lens_slices
step_size_after_lens = propagation_after_lens / num_of_steps_after_lens

# %%
print(delta_x, vacuum_wavelength)
# Out:
# 3.90625e-06 9.999999999999999e-06

# %% [markdown]
# ### Derived objects

# %%
lens_slice_positions = (
    np.linspace(0, lens_thickness, lens_slices, endpoint=False)
    + lens_slice_thickness / 2
)  # choosing the midpoint in each transverse slice

lens_transverse_radii = [
    radius_of_convex_planar_lens_as_a_func_of_z(
        radius_of_curvature, z, lens_thickness, fresnel_approximation=True
    )
    for z in lens_slice_positions
]
print(lens_thickness)
print(lens_slice_positions)
print(lens_transverse_radii)
# Out:
# 0.0005
# [2.50000e-08 7.50000e-08 1.25000e-07 ... 4.99875e-04 4.99925e-04
#  4.99975e-04]
# [np.float64(5e-06), np.float64(8.660254037844387e-06), np.float64(1.1180339887498949e-05), np.float64(1.3228756555322953e-05), np.float64(1.5e-05), np.float64(1.6583123951777e-05), np.float64(1.8027756377319944e-05), np.float64(1.9364916731037083e-05), np.float64(2.06155281280883e-05), np.float64(2.179449471770337e-05), np.float64(2.2912878474779198e-05), np.float64(2.3979157616563598e-05), np.float64(2.4999999999999998e-05), np.float64(2.598076211353316e-05), np.float64(2.692582403567252e-05), np.float64(2.783882181415011e-05), np.float64(2.8722813232690143e-05), np.float64(2.958039891549808e-05), np.float64(3.0413812651491098e-05), np.float64(3.1224989991991994e-05), np.float64(3.201562118716424e-05), np.float64(3.278719262151e-05), np.float64(3.3541019662496847e-05), np.float64(3.427827300200522e-05), np.float64(3.5e-05), np.float64(3.570714214271425e-05), np.float64(3.640054944640259e-05), np.float64(3.708099243547831e-05), np.float64(3.774917217635375e-05), np.float64(3.840572873934304e-05), np.float64(3.905124837953327e-05), np.float64(3.968626966596886e-05), np.float64(4.0311288741492746e-05), np.float64(4.092676385936225e-05), np.float64(4.153311931459037e-05), np.float64(4.213074886588179e-05), np.float64(4.2720018726587654e-05), np.float64(4.330127018922193e-05), np.float64(4.387482193696061e-05), np.float64(4.444097208657795e-05), np.float64(4.4999999999999996e-05), np.float64(4.5552167895721496e-05), np.float64(4.609772228646444e-05), np.float64(4.663689526544407e-05), np.float64(4.7169905660283024e-05), np.float64(4.7696960070847284e-05), np.float64(4.8218253804964775e-05), np.float64(4.873397172404482e-05), np.float64(4.924428900898052e-05), np.float64(4.9749371855331e-05), np.float64(5.024937810560445e-05), np.float64(5.0744457825461096e-05), np.float64(5.123475382979799e-05), np.float64(5.172040216394301e-05), np.float64(5.220153254455276e-05), np.float64(5.267826876426369e-05), np.float64(5.315072906367325e-05), np.float64(5.361902647381804e-05), np.float64(5.408326913195984e-05), np.float64(5.454356057317857e-05), np.float64(5.5e-05), np.float64(5.5452682532047086e-05), np.float64(5.5901699437494744e-05), np.float64(5.634713834792323e-05), np.float64(5.678908345800274e-05), np.float64(5.7227615711297986e-05), np.float64(5.766281297335398e-05), np.float64(5.8094750193111255e-05), np.float64(5.852349955359813e-05), np.float64(5.894913061275798e-05), np.float64(5.937171043518959e-05), np.float64(5.979130371550699e-05), np.float64(6.020797289396148e-05), np.float64(6.062177826491071e-05), np.float64(6.103277807866851e-05), np.float64(6.144102863722254e-05), np.float64(6.18465843842649e-05), np.float64(6.224949798994365e-05), np.float64(6.264982043070833e-05), np.float64(6.304760106459245e-05), np.float64(6.34428877022476e-05), np.float64(6.383572667401853e-05), np.float64(6.422616289332564e-05), np.float64(6.461423991660042e-05), np.float64(6.5e-05), np.float64(6.53834841531101e-05), np.float64(6.576473218982952e-05), np.float64(6.614378277661476e-05), np.float64(6.652067347825035e-05), np.float64(6.689544080129826e-05), np.float64(6.726812023536856e-05), np.float64(6.763874629234341e-05), np.float64(6.800735254367722e-05), np.float64(6.837397165588671e-05), np.float64(6.87386354243376e-05), np.float64(6.910137480542625e-05), np.float64(6.946221994724902e-05), np.float64(6.98212002188447e-05), np.float64(7.0178344238091e-05), np.float64(7.053367989832942e-05), np.float64(7.088723439378913e-05), np.float64(7.123903424387503e-05), np.float64(7.158910531638176e-05), np.float64(7.19374728496908e-05), np.float64(7.22841614740048e-05), np.float64(7.262919523166975e-05), np.float64(7.297259759663212e-05), np.float64(7.33143914930759e-05), np.float64(7.365459931328118e-05), np.float64(7.39932429347437e-05), np.float64(7.433034373659252e-05), np.float64(7.466592261534039e-05), np.float64(7.5e-05), np.float64(7.533259586659682e-05), np.float64(7.566372975210778e-05), np.float64(7.599342076785331e-05), np.float64(7.63216876 ...

# %% [markdown]
# ### Approximations checks

# %%
assert (
    gaussian_beam_waist > 10 * vacuum_wavelength
)  # ensure paraxial approximation validity

# %% [markdown]
# ### Axes

# %%
x_axis = PositionAxis(
    num_qubits=num_qubits, delta_x=delta_x, encoding=EncodingType.UNSIGNED
)
k_axis = AngularWavenumberAxis.from_position_axis(x_axis)
# p_axis = MomentumAxis.from_position_axis(x_axis, hbar=hbar)

# %% [markdown]
# ### Initial beam profile

# %%
# def psi_signal_function(x):
#     norm_factor = 1 / (gaussian_sigma * (2 * constants.pi) ** 0.25)
#     return norm_factor * np.exp(-(((x - gaussian_mean) / gaussian_beam_waist) ** 2))


# def psi_signal_function(x):
#     return np.where(
#         (x > 1 / 3) & (x < 2 / 3),
#         1,
#         0,
#     )


# def psi_signal_function(x):
#     signal = np.zeros(dimension)
#     middle = dimension // 2
#     signal[middle - 20 : middle - 15] = 1
#     signal[middle + 15 : middle + 20] = 1
#     return signal

# psi_flat = Statevector.from_label("+" * num_qubits)

# psi = GenericQuantumSignal(x_axis, psi_signal_function)

psi = gaussian_signal(x_axis, gaussian_beam_waist, gaussian_mean)

# print(np.linalg.norm(psi.data) ** 2)
print(gaussian_beam_waist, beam_FWHM, gaussian_mean)
plot_wavefunction(psi.data, normalize=False)
# Out:
# 0.0001698643600576038 0.0002 0.0005
# (<Figure size 1280x480 with 2 Axes>,
#  (<Axes: xlabel='$|x\\rangle$', ylabel='$|\\psi(x)|$'>,
#   <Axes: xlabel='$|x\\rangle$', ylabel='$\\angle\\psi(x)$'>))

# %% [markdown]
# ### Lens potentials

# %%
lens_signals = [
    thin_transparent_plate_signal_generator(
        x_axis=x_axis,
        refractive_index=refractive_index,
        thickness=lens_slice_thickness,
        radius=lens_radius,
        wavelength=vacuum_wavelength,
        scale_down=True,
    )
    for lens_radius in lens_transverse_radii
]

# %%
NUM_OF_PROFILES_TO_PLOT = 5

for i in range(NUM_OF_PROFILES_TO_PLOT):
    plot_wavefunction(lens_signals[i].data, normalize=False)

# %%
plot_wavefunction(lens_signals[-1].data, normalize=False)
# Out:
# (<Figure size 1280x480 with 2 Axes>,
#  (<Axes: xlabel='$|x\\rangle$', ylabel='$|\\psi(x)|$'>,
#   <Axes: xlabel='$|x\\rangle$', ylabel='$\\angle\\psi(x)$'>))

# %%
sum_signal = np.zeros_like(lens_signals[0].data)
for signal in lens_signals:
    sum_signal += signal.data

plot_wavefunction(sum_signal, normalize=False)
# Out:
# (<Figure size 1280x480 with 2 Axes>,
#  (<Axes: xlabel='$|x\\rangle$', ylabel='$|\\psi(x)|$'>,
#   <Axes: xlabel='$|x\\rangle$', ylabel='$\\angle\\psi(x)$'>))

# %% [markdown]
# ---

# %%
current_state = Statevector(psi.data / np.linalg.norm(psi.data))
snapshots = dict([])

snapshots[f"step_{0}"] = current_state

inside_lens_propagation_remained = lens_thickness
total_lenses_simulated = 0
### Lens
for i, lens_radius in enumerate(lens_transverse_radii):
    print(f"Doing lens slice {i + 1}/{lens_slices}")

    lens_signal = lens_signals[i]
    sample_based_lens_signal = (
        ArbitrarySignalForSampleBasedProtocol.from_generic_signal(lens_signal)
    )

    if not np.isclose(np.std(sample_based_lens_signal.data), 0):
        print(f"max value in signal: {np.max(np.abs(sample_based_lens_signal.data))}")
        print(
            f"sum of amplitude square: {np.sum(np.abs(sample_based_lens_signal.data) ** 2)}"
        )
        # continue
        current_state = phase_propagate_state_with_arbitrary_signal(
            current_state, sample_based_lens_signal, max_delta
        )
        total_lenses_simulated += 1

    else:
        print("Skipped the lens slice because it is a flat phase.")

    propagator_signal = free_space_signal_generator(
        k_axis=k_axis,
        delta_t=lens_slice_thickness / c,
        wavelength=vacuum_wavelength,
        c=constants.c,
    )
    propagator = MomentumDomainEvolutionQuadratic(quadratic_signal=propagator_signal)

    current_state = current_state.evolve(propagator)
    inside_lens_propagation_remained -= lens_slice_thickness

    snapshots[f"step_lens_{i}"] = current_state

# remaining propagation once the lens slice grows larger than the simulation window
while inside_lens_propagation_remained > 0:
    propagator_signal = free_space_signal_generator(
        k_axis=k_axis,
        delta_t=inside_lens_propagation_remained / c,
        wavelength=reduced_wavelength,
        c=constants.c,
    )
    propagator = MomentumDomainEvolutionQuadratic(quadratic_signal=propagator_signal)

    current_state = current_state.evolve(propagator)
    inside_lens_propagation_remained -= inside_lens_propagation_remained

snapshots["after_lens"] = current_state

for i in range(num_of_steps_after_lens):
    print(f"Doing free space step {i + 1}/{num_of_steps_after_lens}")

    propagator_signal = free_space_signal_generator(
        k_axis=k_axis,
        delta_t=step_size_after_lens / c,
        wavelength=vacuum_wavelength,
        c=constants.c,
    )
    propagator = MomentumDomainEvolutionQuadratic(quadratic_signal=propagator_signal)

    current_state = current_state.evolve(propagator)
    snapshots[f"step_after_lens_{i + 1}"] = current_state

snapshots["final"] = current_state
# Out:
# Doing lens slice 1/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0001850550825204255
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 2/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0003084251375340425
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 3/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0003084251375340425
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 4/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.00043179519254765947
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 5/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.00043179519254765947
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 6/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0005551652475612764
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 7/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0005551652475612764
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 8/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0005551652475612764
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 9/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0006785353025748934
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 10/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0006785353025748934
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 11/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0006785353025748934
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 12/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0008019053575885105
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 13/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0008019053575885105
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 14/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0008019053575885105
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 15/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0008019053575885105
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 16/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0009252754126021274
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 17/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0009252754126021274
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 18/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0009252754126021274
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 19/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0009252754126021274
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 20/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0009252754126021274
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 21/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0010486454676157443
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 22/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0010486454676157443
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 23/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0010486454676157443
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 24/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0010486454676157443
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 25/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0010486454676157443
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 26/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 27/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 28/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 29/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 30/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 31/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0011720155226293614
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 32/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 33/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 34/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 35/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 36/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 37/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0012953855776429784
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 38/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 39/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 40/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 41/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 42/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 43/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 44/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0014187556326565954
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 45/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 46/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 47/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 48/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 49/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 50/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 51/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 52/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0015421256876702125
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 53/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 54/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 55/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 56/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 57/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 58/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 59/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 60/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0016654957426838293
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 61/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 62/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 63/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 64/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 65/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 66/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 67/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 68/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 69/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0017888657976974465
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 70/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 71/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 72/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 73/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 74/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 75/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 76/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 77/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 78/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0019122358527110632
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 79/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 80/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 81/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 82/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 83/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 84/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 85/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 86/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 87/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 88/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0020356059077246804
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 89/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 90/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 91/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 92/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 93/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 94/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 95/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 96/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 97/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 98/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 99/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.002158975962738297
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 100/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 101/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 102/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 103/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 104/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 105/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 106/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 107/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 108/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 109/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 110/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0022823460177519143
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 111/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 112/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 113/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 114/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 115/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 116/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 117/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 118/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 119/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 120/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 121/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.0024057160727655315
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 122/10000
# ...
# 16
# 17
# 18
# 19
# Doing lens slice 1822/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1823/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1824/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1825/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1826/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1827/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1828/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1829/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# Doing lens slice 1830/10000
# max value in signal: 0.007853981633974483
# sum of amplitude square: 0.009561179263555316
# Here!
# There -2!
# There -1!
# There 2!
# There 3!
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 11
# 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 23
#      19     print(
#      20         f"sum of amplitude square: {np.sum(np.abs(sample_based_lens_signal.data) ** 2)}"
#      21     )
#      22     # continue
# ---> 23     current_state = phase_propagate_state_with_arbitrary_signal(
#      24         current_state, sample_based_lens_signal, max_delta
#      25     )
#      26     total_lenses_simulated += 1
#      28 else:
#
# File ~/my/davani/projects/qiu/packages/qiskit-phase-propagator/src/qiskit_phase_propagator/sample_based_manual.py:249, in phase_propagate_state_with_arbitrary_signal(psi_in, signal, max_delta)
#     245 print("Here!")
#     247 # psi_out = phase_propagate_state(psi_in, deltas, preparable_state)
# --> 249 psi_out = phase_propagate_state_with_constant_delta(
#     250     psi_in, deltas[0], len(deltas), preparable_state
#     251 )
#     253 return psi_out
#
# File ~/my/davani/projects/qiu/packages/qiskit-phase-propagator/src/qiskit_phase_propagator/sample_based_manual.py:190, in phase_propagate_state_with_constant_delta(psi_in, delta, num_cycles, phi)
#     187 print("12")
#     189 # Evolve the input state through the circuit
# --> 190 psi_after_phase_unit = psi_before_phase_unit.evolve(circuit)
#     192 print("13")
#     194 # applying phi de-initializer
#
# File ~/my/davani/projects/qiu/.venv/lib/python3.10/site-packages/qiskit/quantum_info/states/statevector.py:400, in Statevector.evolve(self, other, qargs)
#     398     if self.num_qubits is None:
#     399         raise QiskitError("Cannot apply QuantumCircuit to non-qubit Statevector.")
# --> 400     return self._evolve_instruction(ret, other, qargs=qargs)
#     402 # Evolution by an Operator
#     403 if not isinstance(other, Operator):
#
# File ~/my/davani/projects/qiu/.venv/lib/python3.10/site-packages/qiskit/quantum_info/states/statevector.py:976, in Statevector._evolve_instruction(statevec, obj, qargs)
#     974     else:
#     975         new_qargs = [qargs[qubits[tup]] for tup in instruction.qubits]
# --> 976     Statevector._evolve_instruction(statevec, instruction.operation, qargs=new_qargs)
#     977 return statevec
#
# File ~/my/davani/projects/qiu/.venv/lib/python3.10/site-packages/qiskit/quantum_info/states/statevector.py:976, in Statevector._evolve_instruction(statevec, obj, qargs)
#     974     else:
#     975         new_qargs = [qargs[qubits[tup]] for tup in instruction.qubits]
# --> 976     Statevector._evolve_instruction(statevec, instruction.operation, qargs=new_qargs)
#     977 return statevec
#
# File ~/my/davani/projects/qiu/.venv/lib/python3.10/site-packages/qiskit/quantum_info/states/statevector.py:918, in Statevector._evolve_instruction(statevec, obj, qargs)
#     914 mat = Operator._instruction_to_matrix(obj)
#     915 if mat is not None:
#     916     # Perform the composition and inplace update the current state
#     917     # of the operator
# --> 918     return Statevector._evolve_operator(statevec, Operator(mat), qargs=qargs)
#     920 # Special instruction types
#     921 if isinstance(obj, Reset):
#
# File ~/my/davani/projects/qiu/.venv/lib/python3.10/site-packages/qiskit/quantum_info/states/statevector.py:891, in Statevector._evolve_operator(statevec, oper, qargs)
#     887 tensor_shape = tensor.shape
#     889 # Perform contraction
#     890 tensor = np.reshape(
# --> 891     np.dot(oper.data, np.reshape(tensor, contract_shape)),
#     892     tensor_shape,
#     893 )
#     895 # Transpose back to  original subsystem spec and flatten
#     896 statevec._data = np.reshape(np.transpose(tensor, axes_inv), new_shape.shape[0])
#
# KeyboardInterrupt:

# %%
save_numpy_results(snapshots, experiment_datetime, wrapper_folder=JUPYTER_NAME)
initial_parameters = {
    "timestamp": experiment_datetime.isoformat(),
    "vacuum_wavelength": vacuum_wavelength,
    "beam_FWHM": beam_FWHM,
    "focal_length": focal_length,
    "lens_diameter": lens_diameter,
    "refractive_index": refractive_index,
    "lens_thickness": lens_thickness,
    "propagation_after_lens": propagation_after_lens,
    "transverse_length": transverse_length,
    "num_of_steps_after_lens": num_of_steps_after_lens,
    "lens_slices": lens_slices,
    "num_qubits": num_qubits,
    "max_delta": max_delta,
    "total_lenses_simulated": total_lenses_simulated,
}
save_initial_parameters(
    initial_parameters, experiment_datetime, wrapper_folder=JUPYTER_NAME
)

# %%
data = snapshots

# %%
# def process_statevector(statevector):
#     return statevector
def process_statevector(statevector):
    """Process the statevector to extract position probabilities."""
    # n = statevector.num_qubits
    # rho = partial_trace(statevector, np.arange(int(n // 2), n).tolist())
    # reduced_state = rho.to_statevector()

    # return reduced_state
    return statevector


initial_statevector = process_statevector(data[f"step_{0}"])

lens_statevectors = [
    process_statevector(data[f"step_lens_{i}"]) if f"step_lens_{i}" in data else None
    for i in range(lens_slices)
]
after_lens_statevectors = [
    process_statevector(data[f"step_after_lens_{i + 1}"])
    if f"step_after_lens_{i + 1}" in data
    else None
    for i in range(num_of_steps_after_lens)
]

# %%
print("Plotting initial state")
plot_wavefunction(initial_statevector, plot_size_scale=1, normalize=True)
plt.suptitle("Initial state")
plt.show()

NUM_OF_LENS_SLICES_TO_PLOT = 5
NUM_OF_AFTER_LENS_SLICES_TO_PLOT = 5

for i, statevector in enumerate(lens_statevectors):
    if statevector is None:
        continue
    if (
        total_lenses_simulated > NUM_OF_LENS_SLICES_TO_PLOT
        and i % (total_lenses_simulated // NUM_OF_LENS_SLICES_TO_PLOT) != 0
    ):
        continue

    print(f"Plotting lens slice {i + 1}/{lens_slices}")

    fig, (ax1, ax2) = plot_wavefunction(statevector, plot_size_scale=1, normalize=True)

    z = lens_slice_thickness * (i + 1)
    R_z, w_z = propagated_gaussian_wavefront_hitting_lens(
        gaussian_beam_waist, z, focal_length, vacuum_wavelength, refractive_index
    )
    signal = gaussian_signal(x_axis, w_z, gaussian_mean)
    ax1.plot(np.abs(signal.normalized_data), "r--", label="thin lens analytical")

    plt.suptitle(f"After lens slice {i + 1}/{lens_slices}")
    plt.show()

for i, statevector in enumerate(after_lens_statevectors):
    if statevector is None:
        continue
    if i % (num_of_steps_after_lens // NUM_OF_AFTER_LENS_SLICES_TO_PLOT) != 0:
        continue

    print(f"Plotting free space step {i + 1}/{num_of_steps_after_lens}")
    fig, (ax1, ax2) = plot_wavefunction(statevector, plot_size_scale=1, normalize=True)

    z = step_size_after_lens * (i + 1) + lens_thickness
    R_z, w_z = free_space_propagated_gaussian_wavefront(
        gaussian_beam_waist, z, vacuum_wavelength, refractive_index=1.0
    )
    signal = gaussian_signal(x_axis, w_z, gaussian_mean)
    ax1.plot(np.abs(signal.normalized_data), "y--", label="free space analytical")

    R_z, w_z = propagated_gaussian_wavefront_hitting_lens(
        gaussian_beam_waist,
        z,
        focal_length,
        vacuum_wavelength,
        refractive_index,
    )
    signal = gaussian_signal(x_axis, w_z, gaussian_mean)
    ax1.plot(np.abs(signal.normalized_data), "r--", label="thin lens analytical")

    plt.suptitle(f"After free space step {i + 1}/{num_of_steps_after_lens}")
    plt.show()
# Out:
# Plotting initial state
# Plotting lens slice 1/100
# Plotting lens slice 21/100
# Plotting lens slice 41/100
# Plotting lens slice 61/100
# Plotting lens slice 81/100
# Plotting free space step 1/10
# Plotting free space step 3/10
# Plotting free space step 5/10
# Plotting free space step 7/10
# Plotting free space step 9/10
